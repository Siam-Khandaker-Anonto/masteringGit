# %% [markdown]
# <a href="https://colab.research.google.com/github/Siam-Khandaker-Anonto/masteringGit/blob/main/JupFirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter a number: "));

if(a > 0):
  print("Success")
else:
  print("Failed")
# Out:
# Enter a number: 5
# Success
